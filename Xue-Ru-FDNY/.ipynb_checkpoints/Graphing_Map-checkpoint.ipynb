# %%
#Heap Map for census tract base on number of reports/ and capital, report per person


import os
import pandas as pd
import geopandas as gpd
import platform
import matplotlib.pyplot as plt
import contextily as ctx
from tabulate import tabulate
import numpy as np
import matplotlib.colors as mcolors

#shp_file = 'tl_2019_36_tract/tl_2019_36_tract.shp'
shp_file = 'ShapeFiles/nyu_2451_34505/nyu_2451_34505.shp'
#shp_file = 'NYC_Census_Tracts_for_2010_US_Census/NYC_Census_Tracts_for_2010_US_Census.shp'
csvfile = 'DataFiles/FDNY/Geoid_Count2017_18.csv'
us_tract = gpd.read_file(shp_file)
data = pd.read_csv(csvfile)

Season = [['03','04','05'],['06','07','08'],['09','10','11'],['12','01','02']]
Season_word = ['Spring','Summer','Autumn','Winter']
#Month = ['01','02','03','04','05','06','07','08','09','10','11','12']
#Month_word = ['January','February','March','April','May','June','July','August','September','October','November','December']
for i in range(0,4):
    Month_data = pd.DataFrame(columns = ['Time','Geoid','NumberOfReports']) # create a new Dataframe with each month
    info = np.array(['SpringCT36047089000','SpringCT36081043701']) 
    count = np.array([0,0])   
    for row in range(0,len(data)): # counting all data seasonly
        # creating a string with all the details we need
        if data.iat[row,0][0:2] == Season[i][0] or data.iat[row,0][0:2] == Season[i][1] or data.iat[row,0][0:2] == Season[i][2]:
            detail = Season_word[i] + 'CT' + str(data.iat[row,1])

            if detail in info:                          # if the string already exist, we will just increment the count
                itemindex = np.where(info == detail)
                count[itemindex[0][0]] += data.iat[row,2]
            else:                                       # else we will have to add the string to info array and create an extra count
                info = np.append(info,detail)
                count = np.append(count,data.iat[row,2])
    
    for row in range(0,len(info)):
        Month_data = Month_data.append({'Time' : info[row][0:6], 'Geoid' : info[row][8:],  'NumberOfReports': count[row] } , ignore_index=True)

    us_tract['Geoid'] = us_tract['tractid'].str.upper()              # create a new column of the same name as DF from 'NAME'
                                                                    # In shp file, the "NAME" is the census tract
                                                                    # In shp file, the "tractid" is the geoid
    us_tract['Geoid'] = us_tract.Geoid.astype(float)        # Conver type to float so we can merge the DFs
                                                                 # We use merge to pass in the data(NumOfReports)from the csv
    Month_data['Geoid'] = Month_data.Geoid.astype(float)
    Month_data['NumberOfReports'] = Month_data.NumberOfReports.astype(int)
    join = us_tract.merge(Month_data, on='Geoid')
    Total = join['NumberOfReports'].sum()


    #plot with background map
    cmap = plt.get_cmap('Reds')
    norm = mcolors.BoundaryNorm(np.arange(0,101,10), cmap.N)
    df = join.to_crs(epsg=3857) 
    ax = df.plot(column='NumberOfReports',cmap='Reds',figsize = (10,8),alpha = 0.8,legend = True,norm = norm)
    ax.set_title(label = 'Number of Gas Leak Reports per Census Tract (' + Season_word[i] + ')' + '( Total number of reports: '+ str(Total)+')', fontdict={'fontsize': 16}, loc='center')
    ctx.add_basemap(ax,zoom = 12)
# color bar increase in steps
# max for different color
# pattern in the gas report, what related to , when and why it happened
# interactive visualization
# dash board - map, parallel coord, scatter plot

#correlation of 2 values

# %%
demographic = pd.read_csv('DataFiles/Crime and Demographics/filtered_CensusTract_Demographic_Data_NYCWestchester_filtered.csv')

print(demographic)
# Out:
#                     GEO.id      GEO.id2  \
# 0                       Id          Id2
# 1     1400000US36005000100  36005000100
# 2     1400000US36005000200  36005000200
# 3     1400000US36005000400  36005000400
# 4     1400000US36005001600  36005001600
# ...                    ...          ...
# 2338  1400000US36119981000  36119981000
# 2339  1400000US36119982000  36119982000
# 2340  1400000US36119983000  36119983000
# 2341  1400000US36119984000  36119984000
# 2342  1400000US36119985000  36119985000
#
#                                     GEO.display-label  \
# 0                                           Geography
# 1              Census Tract 1, Bronx County, New York
# 2              Census Tract 2, Bronx County, New York
# 3              Census Tract 4, Bronx County, New York
# 4             Census Tract 16, Bronx County, New York
# ...                                               ...
# 2338  Census Tract 9810, Westchester County, New York
# 2339  Census Tract 9820, Westchester County, New York
# 2340  Census Tract 9830, Westchester County, New York
# 2341  Census Tract 9840, Westchester County, New York
# 2342  Census Tract 9850, Westchester County, New York
#
#                           HC01_EST_VC01                     HC02_EST_VC01  \
# 0     Total; Estimate; Total population  Male; Estimate; Total population
# 1                                 11517                             10337
# 2                                  4286                              2046
# 3                                  4893                              2490
# 4                                  5140                              2381
# ...                                 ...                               ...
# 2338                               2295                              1815
# 2339                               1721                              1721
# 2340                               1367                                 0
# 2341                                399                               315
# 2342                                927                               422
#
#                            HC03_EST_VC01  \
# 0     Female; Estimate; Total population
# 1                                   1180
# 2                                   2240
# 3                                   2403
# 4                                   2759
# ...                                  ...
# 2338                                 480
# 2339                                   0
# 2340                                1367
# 2341                                  84
# 2342                                 505
#
#                              HC01_EST_VC03  \
# 0     Total; Estimate; AGE - Under 5 years
# 1                                        0
# 2                                      6.3
# 3                                      5.2
# 4                                      6.8
# ...                                    ...
# 2338                                     0
# 2339                                     0
# 2340                                     0
# 2341                                     0
# 2342                                     0
#
#                             HC02_EST_VC03  \
# 0     Male; Estimate; AGE - Under 5 years
# 1                                       0
# 2                                     4.3
# 3                                     6.2
# 4                                     8.3
# ...                                   ...
# 2338                                    0
# 2339                                    0
# 2340                                    -
# 2341                                    0
# 2342                                    0
#
#                               HC03_EST_VC03  \
# 0     Female; Estimate; AGE - Under 5 years
# 1                                         0
# 2                                       8.2
# 3                                       4.1
# 4                                       5.4
# ...                                     ...
# 2338                                      0
# 2339                                      -
# 2340                                      0
# 2341                                      0
# 2342                                      0
#
#                             HC01_EST_VC04  ...  \
# 0     Total; Estimate; AGE - 5 to 9 years  ...
# 1                                       0  ...
# 2                                     9.3  ...
# 3                                     6.7  ...
# 4                                     6.3  ...
# ...                                   ...  ...
# 2338                                    0  ...
# 2339                                    0  ...
# 2340                                    0  ...
# 2341                                    0  ...
# 2342                                    0  ...
#
#                                           HC03_EST_VC32  \
# 0     Female; Estimate; SELECTED AGE CATEGORIES - 75...
# 1                                                     0
# 2                                                   6.3
# 3                                                   4.9
# 4                                                   7.5
# ...                                                 ...
# 2338                                                2.9
# 2339                                                  -
# 2340                                                  0
# 2341                                                  0
# 2342                                                  0
#
#                                           HC01_EST_VC35  \
# 0     Total; Estimate; SUMMARY INDICATORS - Median a...
# 1                                                  31.4
# 2                                                    29
# 3                                                  36.1
# 4                                                  40.2
# ...                                                 ...
# 2338                                               34.8
# 2339                                               39.4
# 2340                                                 36
# 2341                                               56.3
# 2342                                               18.9
#
#                                           HC02_EST_VC35  \
# 0     Male; Estimate; SUMMARY INDICATORS - Median ag...
# 1                                                  30.6
# 2                                                  32.4
# 3                                                  34.4
# 4                                                  37.3
# ...                                                 ...
# 2338                                               38.3
# 2339                                               39.4
# 2340                                                  -
# 2341                                               56.4
# 2342                                               18.9
#
#                                           HC03_EST_VC35  \
# 0     Female; Estimate; SUMMARY INDICATORS - Median ...
# 1                                                    39
# 2                                                  28.8
# 3                                                  37.4
# 4                                                  40.7
# ...                                                 ...
# 2338                                               27.1
# 2339                                                  -
# 2340                                                 36
# 2341                                               47.8
# 2342                                               18.9
#
#                                           HC01_EST_VC36  \
# 0     Total; Estimate; SUMMARY INDICATORS - Sex rati...
# 1                                                   876
# 2                                                  91.3
# 3                                                 103.6
# 4                                                  86.3
# ...                                                 ...
# 2338                                              378.1
# 2339                                                  -
# 2340                                                  -
# 2341                                                375
# 2342                                               83.6
#
#                                           HC01_EST_VC37  \
# 0     Total; Estimate; SUMMARY INDICATORS - Age depe...
# 1                                                   4.8
# 2                                                  58.9
# 3                                                  48.4
# 4                                                  67.5
# ...                                                 ...
# 2338                                                4.5
# 2339                                                0.5
# 2340                                                1.6
# 2341                                               16.3
# 2342                                                  -
#
#                                           HC01_EST_VC38  \
# 0     Total; Estimate; SUMMARY INDICATORS - Age depe...
# 1                                                   0.4
# 2                                                  12.6
# 3                                                  12.2
# 4                                                    21
# ...                                                 ...
# 2338                                                2.1
# 2339                                                0.5
# 2340                                                0.7
# 2341                                               16.3
# 2342                                                  -
#
#                                           HC01_EST_VC39  \
# 0     Total; Estimate; SUMMARY INDICATORS - Age depe...
# 1                                                   4.4
# 2                                                  46.3
# 3                                                  36.2
# 4                                                  46.5
# ...                                                 ...
# 2338                                                2.3
# 2339                                                  -
# 2340                                                0.8
# 2341                                                  -
# 2342                                                  -
#
#                                HC01_EST_VC42  \
# 0     Total; Estimate; PERCENT IMPUTED - Sex
# 1                                        1.4
# 2                                          0
# 3                                          0
# 4                                        0.1
# ...                                      ...
# 2338                                     0.8
# 2339                                     0.5
# 2340                                       0
# 2341                                       0
# 2342                                       0
#
#                                HC01_EST_VC43
# 0     Total; Estimate; PERCENT IMPUTED - Age
# 1                                       19.9
# 2                                        3.3
# 3                                        2.8
# 4                                        0.4
# ...                                      ...
# 2338                                     4.2
# 2339                                       0
# 2340                                       0
# 2341                                     3.3
# 2342                                       0
#
# [2343 rows x 99 columns]

# %%
new_df = demographic[['HC01_EST_VC01','GEO.id2']][1:].copy()

new_df['Geoid'] = new_df['GEO.id2'].str.upper()

print(new_df)
# Out:
#      HC01_EST_VC01      GEO.id2        Geoid
# 1            11517  36005000100  36005000100
# 2             4286  36005000200  36005000200
# 3             4893  36005000400  36005000400
# 4             5140  36005001600  36005001600
# 5             2142  36005001900  36005001900
# ...            ...          ...          ...
# 2338          2295  36119981000  36119981000
# 2339          1721  36119982000  36119982000
# 2340          1367  36119983000  36119983000
# 2341           399  36119984000  36119984000
# 2342           927  36119985000  36119985000
#
# [2342 rows x 3 columns]
# object

# %%
Season = [['03','04','05'],['06','07','08'],['09','10','11'],['12','01','02']]
Season_word = ['Spring','Summer','Autumn','Winter']

for i in range(0,4):
    Month_data = pd.DataFrame(columns = ['Time','Geoid','NumberOfReports']) # create a new Dataframe with each month
    info = np.array(['SpringCT36047089000','SpringCT36081043701']) 
    count = np.array([0,0])   
    for row in range(0,len(data)): # counting all data seasonly
        # creating a string with all the details we need
        if data.iat[row,0][0:2] == Season[i][0] or data.iat[row,0][0:2] == Season[i][1] or data.iat[row,0][0:2] == Season[i][2]:
            detail = Season_word[i] + 'CT' + str(data.iat[row,1])

            if detail in info:                          # if the string already exist, we will just increment the count
                itemindex = np.where(info == detail)
                count[itemindex[0][0]] += data.iat[row,2]
            else:                                       # else we will have to add the string to info array and create an extra count
                info = np.append(info,detail)
                count = np.append(count,data.iat[row,2])
    
    for row in range(0,len(info)):
        Month_data = Month_data.append({'Time' : info[row][0:6], 'Geoid' : info[row][8:],  'NumberOfReports': count[row] } , ignore_index=True)

    us_tract['Geoid'] = us_tract['tractid'].str.upper()              # create a new column of the same name as DF from 'NAME'
                                                                    # In shp file, the "NAME" is the census tract
                                                                    # In shp file, the "tractid" is the geoid
    us_tract['Geoid'] = us_tract.Geoid.astype(float)        # Conver type to float so we can merge the DFs
    new_df['Geoid'] = new_df.Geoid.astype(float)                                                             # We use merge to pass in the data(NumOfReports)from the csv
    new_df['population'] = new_df.HC01_EST_VC01.astype(float)
    Month_data['Geoid'] = Month_data.Geoid.astype(float)
    Month_data['NumberOfReports'] = Month_data.NumberOfReports.astype(float)
    Month_data = Month_data.merge(new_df,on = 'Geoid')
    join = us_tract.merge(Month_data, on='Geoid')
    join['capita'] = join['NumberOfReports']/join['population']


    #plot with background map
    cmap = plt.get_cmap('Reds')
    norm = mcolors.BoundaryNorm(np.arange(0,0.0151,0.001), cmap.N)
    df = join.to_crs(epsg=3857) 
    ax = df.plot(column='capita',cmap='Reds',figsize = (10,8),alpha = 0.8,legend = True,norm = norm)
    ax.set_title(label = 'Number of Gas Leak Reports per person in Census Tract (' + Season_word[i] + ')', fontdict={'fontsize': 16}, loc='center')
    ctx.add_basemap(ax,zoom = 12)

# %%
print(join.capita)
# Out:
# 0       0.001867
# 1       0.000613
# 2       0.001167
# 3       0.005602
# 4       0.002159
#           ...
# 1719    0.000157
# 1720    0.001102
# 1721    0.000151
# 1722    0.001650
# 1723    0.001679
# Name: capita, Length: 1724, dtype: float64

# %%
demo = pd.read_csv("DataFiles/FDNY/Demographic.csv")
print(demo)
# Out:
#             Geoid                              County Population Povertyrate  \
# 0     36001013100     Albany County, Census Tract 131      2,620       6.80%
# 1     36001014700     Albany County, Census Tract 147      2,692       2.60%
# 2     36001014802  Albany County, Census Tract 148.02      1,843      10.70%
# 3     36001013901  Albany County, Census Tract 139.01      2,460       3.30%
# 4     36001013902  Albany County, Census Tract 139.02      5,333       4.00%
# ...           ...                                 ...        ...         ...
# 4913  36123150500     Yates County, Census Tract 1505      4,524      13.60%
# 4914  36123150100     Yates County, Census Tract 1501      5,942      12.00%
# 4915  36123150200     Yates County, Census Tract 1502      5,561      11.30%
# 4916  36123150300     Yates County, Census Tract 1503      5,348      12.90%
# 4917  36123150400     Yates County, Census Tract 1504      3,973       4.30%
#
#      Unemploymentrate
# 0               7.90%
# 1               5.00%
# 2               1.70%
# 3               3.00%
# 4               3.80%
# ...               ...
# 4913            4.70%
# 4914            5.70%
# 4915            5.70%
# 4916            3.30%
# 4917            3.30%
#
# [4918 rows x 5 columns]

# %%
#for i in range(0,4):
#    Month_data = pd.DataFrame(columns = ['Time','Geoid','NumberOfReports']) # create a new Dataframe with each month
#    for row in range(0,len(data)):
#        if data.iat[row,0][0:2] == Season[i][0] or data.iat[row,0][0:2] == Season[i][1] or data.iat[row,0][0:2] == Season[i][2]:    
#            Month_data = Month_data.append({'Time' : Season_word[i], 'Geoid' : data.iat[row,1],  'NumberOfReports': data.iat[row,2] } , ignore_index=True)#

#    for row in range(0,len(Month_data)):
#        if Month_data.iat[row,2] >= 20:
#            print(Month_data.loc[[row]])
#            print()
            
# Average population: 3000 - 4000 per census tract            
# The one on top corner of bronx is 36005046201  (186 total point)
#                       Population: 28272,  area: 0.8 square mile
# The one on the right-mid section of brooklyn is very small: 36047091000 (131 total points)
#                               (super highlighted for December)

# %%
vertify = gpd.read_file(shp_file)
vertify['Geoid'] = vertify['tractid'].str.upper()
vertify['Geoid'] = vertify.Geoid.astype(int)
data['Geoid'] = data.Geoid.astype(float)
data['NumberOfReports'] = data.NumberOfReports.astype(int)
test = vertify.merge(data, on='Geoid')
count = 0
count2 = 0
for row in range(0,len(test)):
    if test.at[row,'Geoid'] == 36005046201:
        count += test.at[row,'NumberOfReports']
    elif test.at[row,'Geoid'] == 36047091000:
        count2 += test.at[row,'NumberOfReports']
        
print(count)
print(count2)
# Out:
# 186
# 131

# %%
nyc = ['005',    '047',     '061',   '081',    '085']
    # bronx     kings     new york   queens   richmond
    #        (brooklyn)  (manhatton)          (staten island)
population = [1432000,2533000,1629000,2273000,476200]
reportcount = [0,0,0,0,0]

for row in range(0,len(test)):
    if test.at[row,'bcode'][2:] == nyc[0]:
        reportcount[0] += test.at[row,'NumberOfReports']
    elif test.at[row,'bcode'][2:] == nyc[1]:
        reportcount[1] += test.at[row,'NumberOfReports']
    elif test.at[row,'bcode'][2:] == nyc[2]:
        reportcount[2] += test.at[row,'NumberOfReports']
    elif test.at[row,'bcode'][2:] == nyc[3]:
        reportcount[3] += test.at[row,'NumberOfReports']
    elif test.at[row,'bcode'][2:] == nyc[4]:
        reportcount[4] += test.at[row,'NumberOfReports']
        
# when added up all the number we get from report count we also get total number 
# of reports from the FDNY2018.csv

# %%
table = [['Bronx',reportcount[0],reportcount[0]/population[0]], ['Brooklyn',reportcount[1],reportcount[1]/population[1]], 
         ['Manhatton',reportcount[2],reportcount[2]/population[2]],['Queens',reportcount[3],reportcount[3]/population[3]], 
         ['Staten Island',reportcount[4],reportcount[4]/population[4]]]
print(tabulate(table, headers=["Borough","Gas Leak Report per Borough","Population/Number of Report"],tablefmt="github"))
# Out:
# | Borough       |   Gas Leak Report per Borough |   Population/Number of Report |
# |---------------|-------------------------------|-------------------------------|
# | Bronx         |                          5209 |                    0.00363757 |
# | Brooklyn      |                          6396 |                    0.00252507 |
# | Manhatton     |                          6300 |                    0.0038674  |
# | Queens        |                          3890 |                    0.00171139 |
# | Staten Island |                           889 |                    0.00186686 |

# %%
###map per capital. popu/number of report for census tract
