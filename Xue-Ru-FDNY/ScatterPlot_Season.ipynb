# %%
#Scatterplots for different demorgraphic data/ population, season over season, poverty rate, unemployment rate
# with and without outlayers.




import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px

# %%
csvfile = 'DataFiles/FDNY/Geoid_Count2017_18.csv'
data = pd.read_csv(csvfile)

Season = [['03','04','05'],['06','07','08'],['09','10','11'],['12','01','02']]
Season_word = ['Spring','Summer','Autumn','Winter']
Month_data = pd.DataFrame(columns = ['Geoid','Spring','Summer','Autumn','Winter']) # create a new Dataframe with each month
info = np.array(['36005046201','36047091000'])
Spring_Count = np.array([0,0])
Summer_Count = np.array([0,0])
Autumn_Count = np.array([0,0])
Winter_Count = np.array([0,0])

for row in range(0,len(data)): 
    
    detail = str(data.iat[row,1])
        
    if detail in info:                          # if the string already exist, we will just increment the count
        itemindex = np.where(info == detail)
    else:                                       # else we will have to add the string to info array and create an extra count
        info = np.append(info,detail)
        Spring_Count = np.append(Spring_Count,0)
        Summer_Count = np.append(Summer_Count,0)
        Autumn_Count = np.append(Autumn_Count,0)
        Winter_Count = np.append(Winter_Count,0)
        itemindex = np.where(info == detail)
        
    if data.iat[row,0][0:2] == '03' or data.iat[row,0][0:2] == '04' or data.iat[row,0][0:2] == '05':
        Spring_Count[itemindex[0][0]] += data.iat[row,2]
    elif data.iat[row,0][0:2] == '06' or data.iat[row,0][0:2] == '07' or data.iat[row,0][0:2] == '08':
        Summer_Count[itemindex[0][0]] += data.iat[row,2]
    elif data.iat[row,0][0:2] == '09' or data.iat[row,0][0:2] == '10' or data.iat[row,0][0:2] == '11':
        Autumn_Count[itemindex[0][0]] += data.iat[row,2]
    elif data.iat[row,0][0:2] == '12' or data.iat[row,0][0:2] == '01' or data.iat[row,0][0:2] == '02':
        Winter_Count[itemindex[0][0]] += data.iat[row,2]
    
for row in range(0,len(info)):
    Month_data = Month_data.append({'Geoid' : info[row], 'Spring' : Spring_Count[row],  'Summer': Summer_Count[row], 'Autumn' : Autumn_Count[row], 'Winter' : Winter_Count[row] } , ignore_index=True)
print(Month_data)
# Out:
#             Geoid Spring Summer Autumn Winter
# 0     36005046201     77     97     99     77
# 1     36047091000     37     62     71     51
# 2     36047089000     10     11     12     14
# 3     36081043701      1      2      1      5
# 4     36005022403      7      8      8     15
# ...           ...    ...    ...    ...    ...
# 2033  36085022300      0      0      0      1
# 2034  36119010300      0      0      0      1
# 2035  36081120300      0      0      0      1
# 2036  36081077300      0      0      0      1
# 2037  36047052800      0      0      0      1
#
# [2038 rows x 5 columns]

# %%
#Month_data.to_csv('DataFiles/FDNY/Season2018.csv', encoding='utf-8',index=False)

# %%
Month_data = pd.read_csv('DataFiles/FDNY/Season2017_18.csv')
Spring = Month_data.Spring.values
Summer = Month_data.Summer.values
Autumn = Month_data.Autumn.values
Winter = Month_data.Winter.values
vmin = 0
vmax = 500
step = 50


print('GRAPHS WITH OUTLIERS')


plt.scatter(Winter,Spring, color='Green',alpha = 0.1)
plt.xlabel('Number of Gas Leak report for a census tract(Winter)')
plt.ylabel('Number of Gas Leak report for a census tract(Spring)')
plt.title('Number of Gas Leak Report within NYC \n Winter vs Spring')
plt.yticks(np.arange(vmin, vmax, step))
plt.xticks(np.arange(vmin, vmax, step))
plt.show()

plt.scatter(Spring,Summer, color='Green',alpha = 0.1)
plt.xlabel('Number of Gas Leak report for a census tract(Spring)')
plt.ylabel('Number of Gas Leak report for a census tract(Summer)')
plt.title('Number of Gas Leak Report within NYC \n Spring vs Summer')
plt.yticks(np.arange(vmin, vmax, step))
plt.xticks(np.arange(vmin, vmax, step))
plt.show()

plt.scatter(Summer,Autumn, color='Green',alpha = 0.1)
plt.xlabel('Number of Gas Leak report for a census tract(Summer)')
plt.ylabel('Number of Gas Leak report for a census tract(Autumn)')
plt.title('Number of Gas Leak Report within NYC \n Summer vs Autumn')
plt.yticks(np.arange(vmin, vmax, step))
plt.xticks(np.arange(vmin, vmax, step))
plt.show()

plt.scatter(Autumn,Winter, color='Green',alpha = 0.1)
plt.xlabel('Number of Gas Leak report for a census tract(Autumn)')
plt.ylabel('Number of Gas Leak report for a census tract(Winter)')
plt.title('Number of Gas Leak Report within NYC \n Autumn vs Winter')
plt.yticks(np.arange(vmin, vmax, step))
plt.xticks(np.arange(vmin, vmax, step))
plt.show()
# Out:
# GRAPHS WITH OUTLIERS

# %%
vmin = 0
vmax = 50
step = 5

print('GRAPHS WITHOUT OUTLIERS')

plt.scatter(Winter,Spring, color='Green',alpha = 0.1)
plt.xlabel('Number of Gas Leak report for a census tract(Winter)')
plt.ylabel('Number of Gas Leak report for a census tract(Spring)')
plt.title('Number of Gas Leak Report within NYC \n Winter vs Spring')
plt.yticks(np.arange(vmin, vmax, step))
plt.xticks(np.arange(vmin, vmax, step))
plt.xlim(vmin, vmax)
plt.ylim(vmin, vmax)
plt.show()

plt.scatter(Spring,Summer, color='Green',alpha = 0.1)
plt.xlabel('Number of Gas Leak report for a census tract(Spring)')
plt.ylabel('Number of Gas Leak report for a census tract(Summer)')
plt.title('Number of Gas Leak Report within NYC \n Spring vs Summer')
plt.yticks(np.arange(vmin, vmax, step))
plt.xticks(np.arange(vmin, vmax, step))
plt.xlim(vmin, vmax)
plt.ylim(vmin, vmax)
plt.show()

plt.scatter(Summer,Autumn, color='Green',alpha = 0.1)
plt.xlabel('Number of Gas Leak report for a census tract(Summer)')
plt.ylabel('Number of Gas Leak report for a census tract(Autumn)')
plt.title('Number of Gas Leak Report within NYC \n Summer vs Autumn')
plt.yticks(np.arange(vmin, vmax, step))
plt.xticks(np.arange(vmin, vmax, step))
plt.xlim(vmin, vmax)
plt.ylim(vmin, vmax)
plt.show()

plt.scatter(Autumn,Winter, color='Green',alpha = 0.1)
plt.xlabel('Number of Gas Leak report for a census tract(Autumn)')
plt.ylabel('Number of Gas Leak report for a census tract(Winter)')
plt.title('Number of Gas Leak Report within NYC \n Autumn vs Winter')
plt.yticks(np.arange(vmin, vmax, step))
plt.xticks(np.arange(vmin, vmax, step))
plt.xlim(vmin, vmax)
plt.ylim(vmin, vmax)
plt.show()
# Out:
# GRAPHS WITHOUT OUTLIERS

# %%
df = pd.read_csv('DataFiles/FDNY/Season2017_18.csv')

# %%
#for i in range(0,len(df)):
#    sum = df.at[i,'Spring'] + df.at[i,'Summer'] + df.at[i,'Autumn']+df.at[i,'Winter']
#    if sum > 150:
#        print(df.loc[[i]])

# %%
# create scatter plot per capita
#create scatter plot for unemployment rate and poverty rate with normalize number
# of report per capita

# %%
demo = pd.read_csv("DataFiles/FDNY/Demographic.csv")
join = demo.merge(df,on = "Geoid")

# %%
join['total'] = join['Spring']+join['Summer']+join['Autumn']+join['Winter']
join['popu'] = join['Population'].str.replace(',', '')

# %%
join['total'] = join.total.astype(float)
join['popu'] = join.popu.astype(float)
join['capita'] = join['total']/join['popu']
capita = join.capita.values
join['Povertyrate'] = join['Povertyrate'].str.replace('%', '')
join['Unemploymentrate'] = join['Unemploymentrate'].str.replace('%', '')
join['Povertyrate'] = join.Povertyrate.astype(float)
join['Unemploymentrate'] = join.Unemploymentrate.astype(float)
povertyrate = join.Povertyrate.values
unemploymentrate = join.Unemploymentrate.values

# %%
print('GRAPHS WITH OUTLIERS')

plt.scatter(capita,povertyrate, color='Green',alpha = 0.1)
plt.xlabel('Number of Gas Leak report per person for census tract')
plt.ylabel('Poverty rate percentage for census tract')
plt.title('Number of Gas Leak Report per person in census tracts of NYC \n vs Poverty rate for census tract in NYC')
plt.show()

plt.scatter(capita,unemploymentrate, color='Green',alpha = 0.1)
plt.xlabel('Number of Gas Leak report per person for census tract')
plt.ylabel('Unemployment rate percentage for census tract')
plt.title('Number of Gas Leak Report per person in census tracts of NYC \n vs Unemployment rate for census tract in NYC')
plt.show()

tot = join.total.values
popu = join.popu.values
plt.scatter(popu,tot, color='Green',alpha = 0.1)
plt.ylabel('Number of Gas Leak report per census tract')
plt.xlabel('Population per census tract')
plt.title('Number of Gas Leak Report per census tracts of NYC \n vs Population per census tract in NYC')
plt.show()
# Out:
# GRAPHS WITH OUTLIERS

# %%
df17 = pd.read_csv('DataFiles/FDNY/Season2017.csv')
df18 = pd.read_csv('DataFiles/FDNY/Season2018.csv')

demo = pd.read_csv("DataFiles/FDNY/Demographic.csv")
join17 = demo.merge(df17,on = "Geoid")
join18 = demo.merge(df18,on = "Geoid")

join17['total'] = join17['Spring']+join17['Summer']+join17['Autumn']+join17['Winter']
join17['popu'] = join17['Population'].str.replace(',', '')

join18['total'] = join18['Spring']+join18['Summer']+join18['Autumn']+join18['Winter']
join18['popu'] = join18['Population'].str.replace(',', '')

join17['total'] = join17.total.astype(float)
join17['popu'] = join17.popu.astype(float)
join17['capita'] = join17['total']/join17['popu']
capita17 = join17.capita.values
join17['Povertyrate'] = join17['Povertyrate'].str.replace('%', '')
join17['Unemploymentrate'] = join17['Unemploymentrate'].str.replace('%', '')
join17['Povertyrate'] = join17.Povertyrate.astype(float)
join17['Unemploymentrate'] = join17.Unemploymentrate.astype(float)
povertyrate17 = join17.Povertyrate.values
unemploymentrate17 = join17.Unemploymentrate.values

join18['total'] = join18.total.astype(float)
join18['popu'] = join18.popu.astype(float)
join18['capita'] = join18['total']/join18['popu']
capita18 = join18.capita.values
join18['Povertyrate'] = join18['Povertyrate'].str.replace('%', '')
join18['Unemploymentrate'] = join18['Unemploymentrate'].str.replace('%', '')
join18['Povertyrate'] = join18.Povertyrate.astype(float)
join18['Unemploymentrate'] = join18.Unemploymentrate.astype(float)
povertyrate18 = join18.Povertyrate.values
unemploymentrate18 = join18.Unemploymentrate.values

tot17 = join17.total.values
popu17 = join17.popu.values

tot18 = join18.total.values
popu18 = join18.popu.values

xmin = 0
xmax = 0.0211
xstep = 0.003
size = popu17/40


print('GRAPHS WITHOUT OUTLIERS\n\n')

print('-----------GRAPHS for Demorgraphic data (Proverty rate)-----------')

plt.scatter(capita,povertyrate, color='Green',alpha = 0.15,s = size)
plt.xlabel('Number of Gas Leak report per person for census tract')
plt.ylabel('Poverty rate percentage for census tract')
plt.title('Number of Gas Leak Report per person in census tracts of NYC \n vs Poverty rate for census tract in NYC')
plt.xticks(np.arange(xmin, xmax, xstep))
plt.xlim(xmin, xmax)
plt.show()

plt.scatter(capita17,povertyrate17, color='Green',alpha = 0.15,s = size)
plt.xlabel('Number of Gas Leak report per person for census tract')
plt.ylabel('Poverty rate percentage for census tract')
plt.title('Number of Gas Leak Report per person in census tracts of NYC \n vs Poverty rate for census tract in NYC \n 2017')
plt.xticks(np.arange(xmin, xmax, xstep))
plt.xlim(xmin, xmax)
plt.show()

plt.scatter(capita18,povertyrate18, color='Green',alpha = 0.15,s = size)
plt.xlabel('Number of Gas Leak report per person for census tract')
plt.ylabel('Poverty rate percentage for census tract')
plt.title('Number of Gas Leak Report per person in census tracts of NYC \n vs Poverty rate for census tract in NYC \n 2018')
plt.xticks(np.arange(xmin, xmax, xstep))
plt.xlim(xmin, xmax)
plt.show()


print('\n-----------GRAPHS for Demorgraphic data (Unemployment rate)-----------')

plt.scatter(capita,unemploymentrate, color='Green',alpha = 0.15,s = size)
plt.xlabel('Number of Gas Leak report per person for census tract')
plt.ylabel('Unemployment rate percentage for census tract')
plt.title('Number of Gas Leak Report per person in census tracts of NYC \n vs Unemployment rate for census tract in NYC')
plt.xticks(np.arange(xmin, xmax, xstep))
plt.xlim(xmin, xmax)
plt.show()

plt.scatter(capita17,unemploymentrate17, color='Green',alpha = 0.15,s = size)
plt.xlabel('Number of Gas Leak report per person for census tract')
plt.ylabel('Unemployment rate percentage for census tract')
plt.title('Number of Gas Leak Report per person in census tracts of NYC \n vs Unemployment rate for census tract in NYC \n 2017')
plt.xticks(np.arange(xmin, xmax, xstep))
plt.xlim(xmin, xmax)
plt.show()

plt.scatter(capita18,unemploymentrate18, color='Green',alpha = 0.15,s = size)
plt.xlabel('Number of Gas Leak report per person for census tract')
plt.ylabel('Unemployment rate percentage for census tract')
plt.title('Number of Gas Leak Report per person in census tracts of NYC \n vs Unemployment rate for census tract in NYC \n 2018')
plt.xticks(np.arange(xmin, xmax, xstep))
plt.xlim(xmin, xmax)
plt.show()


print('\n-----------GRAPHS for Population vs Total number of gas leak report-----------')

plt.scatter(popu,tot, color='Green',alpha = 0.15)
plt.ylabel('Number of Gas Leak report per census tract')
plt.xlabel('Population per census tract')
plt.title('Population per census tract in NYC \nvs Number of Gas Leak Report per census tracts of NYC')
plt.yticks(np.arange(0, 200.1, 25))
plt.ylim(0, 200)
plt.xticks(np.arange(0, 10501, 1500))
plt.xlim(0, 10500)
plt.show()

plt.scatter(popu17,tot17, color='Green',alpha = 0.15)
plt.ylabel('Number of Gas Leak report per census tract')
plt.xlabel('Population per census tract')
plt.title('Population per census tract in NYC \nvs Number of Gas Leak Report per census tracts of NYC \n 2017')
plt.yticks(np.arange(0, 200.1, 25))
plt.ylim(0, 200)
plt.xticks(np.arange(0, 10501, 1500))
plt.xlim(0, 10500)
plt.show()

plt.scatter(popu18,tot18, color='Green',alpha = 0.15)
plt.ylabel('Number of Gas Leak report per census tract')
plt.xlabel('Population per census tract')
plt.title('Population per census tract in NYC \nvs Number of Gas Leak Report per census tracts of NYC \n 2018')
plt.yticks(np.arange(0, 200.1, 25))
plt.ylim(0, 200)
plt.xticks(np.arange(0, 10501, 1500))
plt.xlim(0, 10500)
plt.show()
# Out:
# GRAPHS WITHOUT OUTLIERS
#
#
# -----------GRAPHS for Demorgraphic data (Proverty rate)-----------
# -----------GRAPHS for Demorgraphic data (Unemployment rate)-----------
# -----------GRAPHS for Population vs Total number of gas leak report-----------

# %%
# color code these graphs as well, population update here, add crime data in the dimension
